# %% [markdown]
# ## 1. Loading Dataset

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from openai import OpenAI
import time
import os
from dotenv import load_dotenv

# %%
# Load the embedding data
data_for_embedding = pd.read_csv('../data/data_for_embedding.csv')

# Display dataset
data_for_embedding
# Out:
#        product_id                                       product_name  \
# 0        10017413  DKNY Unisex Black & Grey Printed Medium Trolle...
# 1        10016283  EthnoVogue Women Beige & Grey Made to Measure ...
# 2        10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...
# 3        10015921  Raymond Men Blue Self-Design Single-Breasted B...
# 4        10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...
# ...           ...                                                ...
# 11592    10261595  Laceandme Black Lace Non-Wired Lightly Padded ...
# 11593    10262843  Pepe Jeans Men Black Hammock Slim Fit Low-Rise...
# 11594    10261721                 Mochi Women Gold-Toned Solid Heels
# 11595    10261607  612 league Girls Navy Blue & White Printed Reg...
# 11596    10265199  Pepe Jeans Men Black & Grey Striped Polo Colla...
#
#                                                full_text product_brand  \
# 0      dkny unisex black & grey printed medium trolle...          DKNY
# 1      ethnovogue women beige & grey made to measure ...    EthnoVogue
# 2      spykar women pink alexa super skinny fit high-...        SPYKAR
# 3      raymond men blue self-design single-breasted b...       Raymond
# 4      parx men brown & off-white slim fit printed ca...          Parx
# ...                                                  ...           ...
# 11592  laceandme black lace non-wired lightly padded ...     Laceandme
# 11593  pepe jeans men black hammock slim fit low-rise...    Pepe Jeans
# 11594  mochi women gold-toned solid heels. a pair of ...         Mochi
# 11595  612 league girls navy blue & white printed reg...    612 league
# 11596  pepe jeans men black & grey striped polo colla...    Pepe Jeans
#
#        gender primary_color color_group
# 0      Unisex         Black       Black
# 1       Women         Beige       Beige
# 2       Women          Pink        Pink
# 3         Men          Blue        Blue
# 4         Men         White       White
# ...       ...           ...         ...
# 11592   Women           Red         Red
# 11593     Men         Black       Black
# 11594   Women          Gold      Yellow
# 11595   Girls          Blue        Blue
# 11596     Men         Black       Black
#
# [11597 rows x 7 columns]

# %% [markdown]
# ## 2. Generate embeddings using OpenAI

# %%
# Load environment variables from .env file
load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# Initialize OpenAI client
openai_client = OpenAI(api_key=OPENAI_API_KEY)

# %%
# Function to get embedding with retry
def get_embeddings_batch(texts, model="text-embedding-ada-002"):
    max_retry = 3
    for attempt in range(max_retry):
        try:
            response = openai_client.embeddings.create(
                model=model,
                input=texts
            )
            embeddings = [item.embedding for item in response.data]
            return embeddings
        except Exception as e:
            print(f"Batch error: {e}, attempt {attempt+1}")
            time.sleep(2 ** attempt)
    return [None] * len(texts)

# %%
# Generate embeddings
batch_size = 50
all_embeddings = []
texts = data_for_embedding['full_text'].tolist()

total_batches = (len(texts) + batch_size - 1) // batch_size

for i in range(0, len(texts), batch_size):
    batch_texts = texts[i:i+batch_size]
    batch_embeddings = get_embeddings_batch(batch_texts)
    all_embeddings.extend(batch_embeddings)
    print(f"Processed batch {i//batch_size + 1} / {total_batches}")
# Out:
# Processed batch 1 / 232
# Processed batch 2 / 232
# Processed batch 3 / 232
# Processed batch 4 / 232
# Processed batch 5 / 232
# Processed batch 6 / 232
# Processed batch 7 / 232
# Processed batch 8 / 232
# Processed batch 9 / 232
# Processed batch 10 / 232
# Processed batch 11 / 232
# Processed batch 12 / 232
# Processed batch 13 / 232
# Processed batch 14 / 232
# Processed batch 15 / 232
# Processed batch 16 / 232
# Processed batch 17 / 232
# Processed batch 18 / 232
# Processed batch 19 / 232
# Processed batch 20 / 232
# Processed batch 21 / 232
# Processed batch 22 / 232
# Processed batch 23 / 232
# Processed batch 24 / 232
# Processed batch 25 / 232
# Processed batch 26 / 232
# Processed batch 27 / 232
# Processed batch 28 / 232
# Processed batch 29 / 232
# Processed batch 30 / 232
# Processed batch 31 / 232
# Processed batch 32 / 232
# Processed batch 33 / 232
# Processed batch 34 / 232
# Processed batch 35 / 232
# Processed batch 36 / 232
# Processed batch 37 / 232
# Processed batch 38 / 232
# Processed batch 39 / 232
# Processed batch 40 / 232
# Processed batch 41 / 232
# Processed batch 42 / 232
# Processed batch 43 / 232
# Processed batch 44 / 232
# Processed batch 45 / 232
# Processed batch 46 / 232
# Processed batch 47 / 232
# Processed batch 48 / 232
# Processed batch 49 / 232
# Processed batch 50 / 232
# Processed batch 51 / 232
# Processed batch 52 / 232
# Processed batch 53 / 232
# Processed batch 54 / 232
# Processed batch 55 / 232
# Processed batch 56 / 232
# Processed batch 57 / 232
# Processed batch 58 / 232
# Processed batch 59 / 232
# Processed batch 60 / 232
# Processed batch 61 / 232
# Processed batch 62 / 232
# Processed batch 63 / 232
# Processed batch 64 / 232
# Processed batch 65 / 232
# Processed batch 66 / 232
# Processed batch 67 / 232
# Processed batch 68 / 232
# Processed batch 69 / 232
# Processed batch 70 / 232
# Processed batch 71 / 232
# Processed batch 72 / 232
# Processed batch 73 / 232
# Processed batch 74 / 232
# Processed batch 75 / 232
# Processed batch 76 / 232
# Processed batch 77 / 232
# Processed batch 78 / 232
# Processed batch 79 / 232
# Processed batch 80 / 232
# Processed batch 81 / 232
# Processed batch 82 / 232
# Processed batch 83 / 232
# Processed batch 84 / 232
# Processed batch 85 / 232
# Processed batch 86 / 232
# Processed batch 87 / 232
# Processed batch 88 / 232
# Processed batch 89 / 232
# Processed batch 90 / 232
# Processed batch 91 / 232
# Processed batch 92 / 232
# Processed batch 93 / 232
# Processed batch 94 / 232
# Processed batch 95 / 232
# Processed batch 96 / 232
# Processed batch 97 / 232
# Processed batch 98 / 232
# Processed batch 99 / 232
# Processed batch 100 / 232
# Processed batch 101 / 232
# Processed batch 102 / 232
# Processed batch 103 / 232
# Processed batch 104 / 232
# Processed batch 105 / 232
# Processed batch 106 / 232
# Processed batch 107 / 232
# Processed batch 108 / 232
# Processed batch 109 / 232
# Processed batch 110 / 232
# Processed batch 111 / 232
# Processed batch 112 / 232
# Processed batch 113 / 232
# Processed batch 114 / 232
# Processed batch 115 / 232
# Processed batch 116 / 232
# Processed batch 117 / 232
# Processed batch 118 / 232
# Processed batch 119 / 232
# Processed batch 120 / 232
# Processed batch 121 / 232
# Processed batch 122 / 232
# Processed batch 123 / 232
# Processed batch 124 / 232
# Processed batch 125 / 232
# Processed batch 126 / 232
# Processed batch 127 / 232
# Processed batch 128 / 232
# Processed batch 129 / 232
# Processed batch 130 / 232
# Processed batch 131 / 232
# Processed batch 132 / 232
# Processed batch 133 / 232
# Processed batch 134 / 232
# Processed batch 135 / 232
# Processed batch 136 / 232
# Processed batch 137 / 232
# Processed batch 138 / 232
# Processed batch 139 / 232
# Processed batch 140 / 232
# Processed batch 141 / 232
# Processed batch 142 / 232
# Processed batch 143 / 232
# Processed batch 144 / 232
# Processed batch 145 / 232
# Processed batch 146 / 232
# Processed batch 147 / 232
# Processed batch 148 / 232
# Processed batch 149 / 232
# Processed batch 150 / 232
# Processed batch 151 / 232
# Processed batch 152 / 232
# Processed batch 153 / 232
# Processed batch 154 / 232
# Processed batch 155 / 232
# Processed batch 156 / 232
# Processed batch 157 / 232
# Processed batch 158 / 232
# Processed batch 159 / 232
# Processed batch 160 / 232
# Processed batch 161 / 232
# Processed batch 162 / 232
# Processed batch 163 / 232
# Processed batch 164 / 232
# Processed batch 165 / 232
# Processed batch 166 / 232
# Processed batch 167 / 232
# Processed batch 168 / 232
# Processed batch 169 / 232
# Processed batch 170 / 232
# Processed batch 171 / 232
# Processed batch 172 / 232
# Processed batch 173 / 232
# Processed batch 174 / 232
# Processed batch 175 / 232
# Processed batch 176 / 232
# Processed batch 177 / 232
# Processed batch 178 / 232
# Processed batch 179 / 232
# Processed batch 180 / 232
# Processed batch 181 / 232
# Processed batch 182 / 232
# Processed batch 183 / 232
# Processed batch 184 / 232
# Processed batch 185 / 232
# Processed batch 186 / 232
# Processed batch 187 / 232
# Processed batch 188 / 232
# Processed batch 189 / 232
# Processed batch 190 / 232
# Processed batch 191 / 232
# Processed batch 192 / 232
# Processed batch 193 / 232
# Processed batch 194 / 232
# Processed batch 195 / 232
# Processed batch 196 / 232
# Processed batch 197 / 232
# Processed batch 198 / 232
# Processed batch 199 / 232
# Processed batch 200 / 232
# Processed batch 201 / 232
# Processed batch 202 / 232
# Processed batch 203 / 232
# Processed batch 204 / 232
# Processed batch 205 / 232
# Processed batch 206 / 232
# Processed batch 207 / 232
# Processed batch 208 / 232
# Processed batch 209 / 232
# Processed batch 210 / 232
# Processed batch 211 / 232
# Processed batch 212 / 232
# Processed batch 213 / 232
# Processed batch 214 / 232
# Processed batch 215 / 232
# Processed batch 216 / 232
# Processed batch 217 / 232
# Processed batch 218 / 232
# Processed batch 219 / 232
# Processed batch 220 / 232
# Processed batch 221 / 232
# Processed batch 222 / 232
# Processed batch 223 / 232
# Processed batch 224 / 232
# Processed batch 225 / 232
# Processed batch 226 / 232
# Processed batch 227 / 232
# Processed batch 228 / 232
# Processed batch 229 / 232
# Processed batch 230 / 232
# Processed batch 231 / 232
# Processed batch 232 / 232

# %%
# Save embeddings to the DataFrame
data_for_embedding['embedding'] = all_embeddings

data_for_embedding['embedding'].iloc[0]

len(data_for_embedding['embedding'].iloc[0])
# Out:
# 1536

# %% [markdown]
# ## 3. Sanity check for embeddings

# %%
# Check embedding dimension
embedding_lengths = data_for_embedding['embedding'].apply(len)
print(embedding_lengths.value_counts())

# Check for any None values
num_null_embeddings = data_for_embedding['embedding'].apply(lambda x: x is None).sum()
print(f"\nNumber of null embeddings: {num_null_embeddings}")

# Sample random embeddings
print("\nSample embedding from row 0:")
print(data_for_embedding['embedding'].iloc[0][:10])

# Check for all-zero embeddings
num_all_zeros = data_for_embedding['embedding'].apply(lambda x: np.allclose(x, 0)).sum()
print(f"\nNumber of embeddings that are all zeros: {num_all_zeros}")
# Out:
# embedding
# 1536    11597
# Name: count, dtype: int64
#
# Number of null embeddings: 0
#
# Sample embedding from row 0:
# [-0.003466130932793021, -0.0027112476527690887, 0.0174106415361166, -0.04953900724649429, -0.01087831798940897, 0.0036494359374046326, -0.028155647218227386, -0.024289578199386597, -0.00939188152551651, -0.026969164609909058]
#
# Number of embeddings that are all zeros: 0

# %%
data_for_embedding
# Out:
#        product_id                                       product_name  \
# 0        10017413  DKNY Unisex Black & Grey Printed Medium Trolle...
# 1        10016283  EthnoVogue Women Beige & Grey Made to Measure ...
# 2        10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...
# 3        10015921  Raymond Men Blue Self-Design Single-Breasted B...
# 4        10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...
# ...           ...                                                ...
# 11592    10261595  Laceandme Black Lace Non-Wired Lightly Padded ...
# 11593    10262843  Pepe Jeans Men Black Hammock Slim Fit Low-Rise...
# 11594    10261721                 Mochi Women Gold-Toned Solid Heels
# 11595    10261607  612 league Girls Navy Blue & White Printed Reg...
# 11596    10265199  Pepe Jeans Men Black & Grey Striped Polo Colla...
#
#                                                full_text product_brand  \
# 0      dkny unisex black & grey printed medium trolle...          DKNY
# 1      ethnovogue women beige & grey made to measure ...    EthnoVogue
# 2      spykar women pink alexa super skinny fit high-...        SPYKAR
# 3      raymond men blue self-design single-breasted b...       Raymond
# 4      parx men brown & off-white slim fit printed ca...          Parx
# ...                                                  ...           ...
# 11592  laceandme black lace non-wired lightly padded ...     Laceandme
# 11593  pepe jeans men black hammock slim fit low-rise...    Pepe Jeans
# 11594  mochi women gold-toned solid heels. a pair of ...         Mochi
# 11595  612 league girls navy blue & white printed reg...    612 league
# 11596  pepe jeans men black & grey striped polo colla...    Pepe Jeans
#
#        gender primary_color  price_range color_group  \
# 0      Unisex         Black  10000-20000       Black
# 1       Women         Beige   5000-10000       Beige
# 2       Women          Pink     500-1000        Pink
# 3         Men          Blue   5000-10000        Blue
# 4         Men         White     500-1000       White
# ...       ...           ...          ...         ...
# 11592   Women           Red     500-1000         Red
# 11593     Men         Black    1000-1500       Black
# 11594   Women          Gold    1500-2000      Yellow
# 11595   Girls          Blue     500-1000        Blue
# 11596     Men         Black     500-1000       Black
#
#                                                embedding
# 0      [-0.003466130932793021, -0.0027112476527690887...
# 1      [-0.014691106043756008, -0.023677324876189232,...
# 2      [-0.022698599845170975, -0.0005512937204912305...
# 3      [-0.023501304909586906, -0.007294438313692808,...
# 4      [-0.019166795536875725, -0.011621855199337006,...
# ...                                                  ...
# 11592  [-0.029609959572553635, 0.005196043755859137, ...
# 11593  [-0.026133066043257713, -0.019850818440318108,...
# 11594  [-0.007454282604157925, -0.021012337878346443,...
# 11595  [-0.011221136897802353, -0.007862606085836887,...
# 11596  [-0.023140646517276764, -0.020205089822411537,...
#
# [11597 rows x 9 columns]

# %% [markdown]
# ## 4. Save embeddings to disk

# %%
data_for_embedding.to_pickle('../data/embedding_with_metadata.pkl')

print(f"\nEmbedding generation complete.")
# Out:
# Embedding generation complete.
